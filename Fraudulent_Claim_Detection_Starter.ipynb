# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('/content/insurance_claims.csv')

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
df.dropna(subset=['authorities_contacted'], inplace=True)

df.isnull().sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                   0
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                  0
# bodily_injuries                  0
# witnesses                        0
# police_report_available          0
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# auto_make                        0
# auto_model                       0
# auto_year                        0
# fraud_reported                   0
# _c39                           909
# dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for column in df.columns:
    print(f"Column: {column}")
    print(df[column].value_counts(dropna=False))
    print("--------------------")
# Out:
# Column: months_as_customer
# months_as_customer
# 128    7
# 254    7
# 230    7
# 285    7
# 290    6
#       ..
# 161    1
# 9      1
# 141    1
# 381    1
# 191    1
# Name: count, Length: 384, dtype: int64
# --------------------
# Column: age
# age
# 43    45
# 39    43
# 41    43
# 38    40
# 37    39
# 30    38
# 34    36
# 32    36
# 33    35
# 31    35
# 40    34
# 29    32
# 46    31
# 42    30
# 36    29
# 44    29
# 28    28
# 35    26
# 26    25
# 45    24
# 48    23
# 47    22
# 27    21
# 57    14
# 50    13
# 53    13
# 25    12
# 55    12
# 61    10
# 54    10
# 60     9
# 49     9
# 51     8
# 58     8
# 56     8
# 24     8
# 23     7
# 21     6
# 59     4
# 62     4
# 52     4
# 64     2
# 19     1
# 20     1
# 22     1
# 63     1
# Name: count, dtype: int64
# --------------------
# Column: policy_number
# policy_number
# 556080    1
# 521585    1
# 342868    1
# 687698    1
# 227811    1
#          ..
# 143972    1
# 921202    1
# 275265    1
# 558938    1
# 892874    1
# Name: count, Length: 909, dtype: int64
# --------------------
# Column: policy_bind_date
# policy_bind_date
# 2006-01-01    3
# 1992-08-05    3
# 1992-04-28    3
# 1999-12-07    2
# 2014-07-05    2
#              ..
# 2003-07-05    1
# 1995-02-18    1
# 2014-12-13    1
# 1997-06-01    1
# 1998-02-01    1
# Name: count, Length: 865, dtype: int64
# --------------------
# Column: policy_state
# policy_state
# OH    319
# IL    310
# IN    280
# Name: count, dtype: int64
# --------------------
# Column: policy_csl
# policy_csl
# 100/300     326
# 250/500     316
# 500/1000    267
# Name: count, dtype: int64
# --------------------
# Column: policy_deductable
# policy_deductable
# 1000    317
# 500     315
# 2000    277
# Name: count, dtype: int64
# --------------------
# Column: policy_annual_premium
# policy_annual_premium
# 1558.29    2
# 1524.45    2
# 1374.22    2
# 1215.36    2
# 1281.25    2
#           ..
# 1829.63    1
# 904.70     1
# 1243.84    1
# 1030.95    1
# 1365.46    1
# Name: count, Length: 903, dtype: int64
# --------------------
# Column: umbrella_limit
# umbrella_limit
#  0           726
#  6000000      50
#  5000000      43
#  4000000      37
#  7000000      24
#  3000000      11
#  8000000       8
#  9000000       4
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
# --------------------
# Column: insured_zip
# insured_zip
# 477695    2
# 446895    2
# 456602    2
# 469429    2
# 431202    2
#          ..
# 452204    1
# 454530    1
# 474848    1
# 435985    1
# 466634    1
# Name: count, Length: 904, dtype: int64
# --------------------
# Column: insured_sex
# insured_sex
# FEMALE    494
# MALE      415
# Name: count, dtype: int64
# --------------------
# Column: insured_education_level
# insured_education_level
# High School    146
# JD             145
# MD             132
# Masters        130
# Associate      129
# PhD            115
# College        112
# Name: count, dtype: int64
# --------------------
# Column: insured_occupation
# insured_occupation
# machine-op-inspct    87
# prof-specialty       77
# tech-support         71
# craft-repair         70
# sales                70
# exec-managerial      68
# transport-moving     67
# priv-house-serv      66
# other-service        61
# armed-forces         59
# protective-serv      58
# adm-clerical         54
# handlers-cleaners    53
# farming-fishing      48
# Name: count, dtype: int64
# --------------------
# Column: insured_hobbies
# insured_hobbies
# reading           58
# exercise          54
# bungie-jumping    52
# camping           50
# hiking            50
# movies            50
# paintball         49
# yachting          49
# golf              47
# skydiving         47
# kayaking          46
# board-games       43
# video-games       43
# base-jumping      43
# chess             43
# polo              42
# dancing           40
# sleeping          38
# cross-fit         34
# basketball        31
# Name: count, dtype: int64
# --------------------
# Column: insured_relationship
# insured_relationship
# own-child         165
# other-relative    164
# husband           156
# not-in-family     156
# wife              139
# unmarried         129
# Name: count, dtype: int64
# --------------------
# Column: capital-gains
# capital-gains
# 0        466
# 46300      5
# 51500      4
# 38600      3
# 59600      3
#         ...
# 28900      1
# 37500      1
# 77500      1
# 50300      1
# 70900      1
# Name: count, Length: 312, dtype: int64
# --------------------
# Column: capital-loss
# capital-loss
#  0        432
# -50300      5
# -45300      4
# -61400      4
# -31700      4
#          ...
# -55400      1
# -65800      1
# -80800      1
# -21500      1
# -32200      1
# Name: count, Length: 341, dtype: int64
# --------------------
# Column: incident_date
# incident_date
# 2015-02-02    25
# 2015-01-07    24
# 2015-01-10    23
# 2015-02-04    23
# 2015-02-17    23
# 2015-01-24    21
# 2015-01-08    21
# 2015-01-30    20
# 2015-01-19    20
# 2015-02-12    19
# 2015-01-14    19
# 2015-02-06    19
# 2015-02-14    18
# 2015-02-23    18
# 2015-01-13    18
# 2015-01-12    18
# 2015-01-31    18
# 2015-02-01    17
# 2015-02-08    17
# 2015-01-09    17
# 2015-02-22    17
# 2015-01-21    17
# 2015-01-03    16
# 2015-02-21    16
# 2015-01-01    16
# 2015-02-28    16
# 2015-01-06    16
# 2015-02-15    16
# 2015-02-25    16
# 2015-01-20    16
# 2015-02-24    15
# 2015-01-16    15
# 2015-01-18    15
# 2015-02-13    15
# 2015-02-26    14
# 2015-02-18    14
# 2015-02-05    14
# 2015-02-16    14
# 2015-01-15    13
# 2015-01-22    13
# 2015-01-17    13
# 2015-01-23    13
# 2015-02-20    13
# 2015-01-28    13
# 2015-03-01    12
# 2015-01-27    12
# 2015-02-27    12
# 2015-01-04    11
# 2015-02-09    11
# 2015-02-03    11
# 2015-01-29    10
# 2015-01-25    10
# 2015-01-26    10
# 2015-02-11     9
# 2015-01-02     9
# 2015-01-11     9
# 2015-02-07     9
# 2015-02-19     8
# 2015-02-10     7
# 2015-01-05     5
# Name: count, dtype: int64
# --------------------
# Column: incident_type
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                53
# Parked Car                   34
# Name: count, dtype: int64
# --------------------
# Column: collision_type
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                   87
# Name: count, dtype: int64
# --------------------
# Column: incident_severity
# incident_severity
# Minor Damage      304
# Total Loss        280
# Major Damage      276
# Trivial Damage     49
# Name: count, dtype: int64
# --------------------
# Column: authorities_contacted
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
# --------------------
# Column: incident_state
# incident_state
# NY    246
# SC    225
# WV    196
# NC     97
# VA     96
# PA     29
# OH     20
# Name: count, dtype: int64
# --------------------
# Column: incident_city
# incident_city
# Springfield    145
# Columbus       141
# Northbend      133
# Arlington      129
# Hillsdale      128
# Riverwood      121
# Northbrook     112
# Name: count, dtype: int64
# --------------------
# Column: incident_location
# incident_location
# 1416 Cherokee Ridge    1
# 9935 4th Drive         1
# 6608 MLK Hwy           1
# 7121 Francis Lane      1
# 6956 Maple Drive       1
#                       ..
# 8101 3rd Ridge         1
# 3842 Solo Ridge        1
# 4546 Tree St           1
# 5074 3rd St            1
# 9573 Weaver Ave        1
# Name: count, Length: 909, dtype: int64
# --------------------
# Column: incident_hour_of_the_day
# incident_hour_of_the_day
# 23    51
# 17    51
# 0     49
# 16    47
# 14    42
# 13    42
# 21    42
# 12    40
# 10    40
# 3     40
# 18    40
# 19    39
# 22    38
# 4     38
# 15    38
# 9     34
# 7     33
# 6     33
# 20    32
# 11    30
# 2     30
# 8     27
# 1     27
# 5     26
# Name: count, dtype: int64
# --------------------
# Column: number_of_vehicles_involved
# number_of_vehicles_involved
# 1    490
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
# --------------------
# Column: property_damage
# property_damage
# ?      329
# NO     304
# YES    276
# Name: count, dtype: int64
# --------------------
# Column: bodily_injuries
# bodily_injuries
# 2    309
# 0    307
# 1    293
# Name: count, dtype: int64
# --------------------
# Column: witnesses
# witnesses
# 2    234
# 0    230
# 1    228
# 3    217
# Name: count, dtype: int64
# --------------------
# Column: police_report_available
# police_report_available
# ?      316
# NO     307
# YES    286
# Name: count, dtype: int64
# --------------------
# Column: total_claim_amount
# total_claim_amount
# 59400    5
# 60600    4
# 58500    4
# 70400    4
# 44200    4
#         ..
# 7590     1
# 45180    1
# 89520    1
# 68160    1
# 60840    1
# Name: count, Length: 719, dtype: int64
# --------------------
# Column: injury_claim
# injury_claim
# 0        24
# 5540      5
# 13520     5
# 6340      5
# 7420      4
#          ..
# 1380      1
# 12320     1
# 390       1
# 13200     1
# 5140      1
# Name: count, Length: 616, dtype: int64
# --------------------
# Column: property_claim
# property_claim
# 0        18
# 11080     5
# 10000     5
# 5310      4
# 7000      4
#          ..
# 10280     1
# 13580     1
# 16640     1
# 7080      1
# 9420      1
# Name: count, Length: 603, dtype: int64
# --------------------
# Column: vehicle_claim
# vehicle_claim
# 33600    5
# 52080    5
# 44800    5
# 35000    4
# 41580    4
#         ..
# 34720    1
# 53830    1
# 39960    1
# 75600    1
# 34370    1
# Name: count, Length: 691, dtype: int64
# --------------------
# Column: auto_make
# auto_make
# Suburu        74
# Saab          72
# Dodge         72
# Nissan        69
# Ford          67
# BMW           67
# Chevrolet     66
# Audi          63
# Accura        63
# Toyota        62
# Volkswagen    62
# Jeep          62
# Mercedes      60
# Honda         50
# Name: count, dtype: int64
# --------------------
# Column: auto_model
# auto_model
# RAM               40
# Wrangler          38
# A3                33
# Jetta             33
# MDX               33
# Neon              32
# A5                30
# Legacy            30
# Passat            29
# Pathfinder        27
# Forrestor         26
# Camry             25
# Malibu            25
# F150              25
# 95                25
# 92x               24
# E400              24
# Grand Cherokee    24
# Escape            23
# 93                23
# Maxima            23
# Tahoe             22
# X5                20
# Highlander        20
# Fusion            19
# Ultima            19
# Silverado         19
# CRV               19
# TL                19
# Impreza           18
# C300              18
# ML350             18
# Civic             18
# 3 Series          18
# Corolla           17
# X6                16
# M5                13
# Accord            13
# RSX               11
# Name: count, dtype: int64
# --------------------
# Column: auto_year
# auto_year
# 1995    52
# 2006    51
# 2005    51
# 1999    50
# 2007    48
# 2009    47
# 2010    47
# 2011    47
# 2003    46
# 2012    43
# 2013    43
# 2008    42
# 1997    42
# 2015    42
# 2002    41
# 2014    40
# 2000    38
# 2004    36
# 1996    35
# 1998    35
# 2001    33
# Name: count, dtype: int64
# --------------------
# Column: fraud_reported
# fraud_reported
# N    668
# Y    241
# Name: count, dtype: int64
# --------------------
# Column: _c39
# _c39
# NaN    909
# Name: count, dtype: int64
# --------------------

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
columns_name = df.columns[df.isnull().all()]
df.drop(columns_name, axis=1, inplace=True)

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
pos_columns = [
    'months_as_customer', 'age', 'policy_deductable','policy_number', 'policy_annual_premium',
    'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
    'number_of_vehicles_involved', 'bodily_injuries', 'witnesses','insured_zip',
    'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year'
]

for col in pos_columns:
    df = df[df[col] >= 0]

# %%
df.shape
#property_damage, police_report_available
# Out:
# (431, 39)

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
df = df.drop(columns=['policy_number'])

# %%
# Check the dataset
df.head()
# Out:
#    months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                 328   48       2014-10-17           OH    250/500
# 1                 228   42       2006-06-27           IN    250/500
# 2                 134   29       2000-09-06           OH    100/300
# 5                 256   39       2006-10-12           OH    250/500
# 7                 165   37       1990-02-03           IL    100/300
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0               1000                1406.91               0       466132
# 1               2000                1197.22         5000000       468176
# 2               2000                1413.14         5000000       430632
# 5               1000                1351.10               0       478456
# 7               1000                1137.03               0       603195
#
#   insured_sex  ... witnesses police_report_available total_claim_amount  \
# 0        MALE  ...         2                     YES              71610
# 1        MALE  ...         0                       ?               5070
# 2      FEMALE  ...         3                      NO              34650
# 5      FEMALE  ...         2                      NO              64100
# 7        MALE  ...         2                     YES              51590
#
#   injury_claim  property_claim  vehicle_claim auto_make auto_model auto_year  \
# 0         6510           13020          52080      Saab        92x      2004
# 1          780             780           3510  Mercedes       E400      2007
# 2         7700            3850          23100     Dodge        RAM      2007
# 5         6410            6410          51280      Saab         95      2003
# 7         9380            9380          32830      Audi         A5      2015
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 5              Y
# 7              N
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (431, 38)

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
date_columns = ['policy_bind_date', 'incident_date']
for col in date_columns:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
# Check the features of the data again
df.shape
# Out:
# (431, 38)

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
df['fraud_reported'] = df['fraud_reported'].map({'Y': 1, 'N': 0}).astype(int)
X = df.drop(columns=['fraud_reported'])

# Put the target variable in y
y = df['fraud_reported']

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)
# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_columns = X_train.select_dtypes(include=['int64', 'float64']).columns
numerical_columns
# Out:
# Index(['months_as_customer', 'age', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
for col in numerical_columns:
    plt.figure(figsize=(8, 4))
    plt.hist(X_train[col], bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
correlation_matrix = X_train[numerical_columns].corr()
# correlation_matrix
# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Heatmap of the Numerical Features')
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
target_class = y_train.value_counts()
plt.figure(figsize=(6, 4))
target_class.plot(kind='bar')
plt.title('Class Distribution `fraud_reported`')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
def target_likelihood_analysis(data, target, categorical_columns):
    """
    Function to calculate and visualize the target likelihood for categorical features.
    """
    weak_features = []
    for col in categorical_columns:
        combined_df = pd.concat([data[col], target], axis=1)
        likelihood = combined_df.groupby(col)[target.name].apply(lambda x: (x == 1).mean()).sort_values(ascending=False)
        print(f"\nTarget likelihood for {col}:\n")
        print(likelihood)
        max_lik = likelihood.max()
        min_lik = likelihood.min()
        diff = max_lik - min_lik
        if diff < 0.1:
            weak_features.append(col)
            print(f"{col} shows low variation in target likelihood: {diff:.2f} -> Consider removing.")

        ##### Plotting the likelihood
        plt.figure(figsize=(6, 4))
        likelihood.plot(kind='bar')
        plt.title(f'Target Likelihood for the feature {col}')
        plt.ylabel('Likelihood of Fraud Reported `Y`(1)')
        plt.xlabel(col)
        plt.xticks(rotation=45)
        plt.show()
    return weak_features
categorical_columns = X_train.select_dtypes(include=['object']).columns
weak_categorical_features = target_likelihood_analysis(X_train, y_train, categorical_columns)
# Out:
# Target likelihood for policy_state:
#
# policy_state
# OH    0.285714
# IN    0.268041
# IL    0.202020
# Name: fraud_reported, dtype: float64
# policy_state shows low variation in target likelihood: 0.08 -> Consider removing.
# Target likelihood for policy_csl:
#
# policy_csl
# 250/500     0.271028
# 500/1000    0.261905
# 100/300     0.227273
# Name: fraud_reported, dtype: float64
# policy_csl shows low variation in target likelihood: 0.04 -> Consider removing.
# Target likelihood for insured_sex:
#
# insured_sex
# MALE      0.300752
# FEMALE    0.214286
# Name: fraud_reported, dtype: float64
# insured_sex shows low variation in target likelihood: 0.09 -> Consider removing.
# Target likelihood for insured_education_level:
#
# insured_education_level
# MD             0.372093
# Associate      0.324324
# PhD            0.317073
# JD             0.312500
# Masters        0.163265
# High School    0.160000
# College        0.121212
# Name: fraud_reported, dtype: float64
# Target likelihood for insured_occupation:
#
# insured_occupation
# exec-managerial      0.437500
# tech-support         0.368421
# farming-fishing      0.357143
# transport-moving     0.333333
# sales                0.322581
# craft-repair         0.275862
# machine-op-inspct    0.275862
# priv-house-serv      0.217391
# armed-forces         0.217391
# prof-specialty       0.200000
# other-service        0.173913
# protective-serv      0.117647
# adm-clerical         0.076923
# handlers-cleaners    0.066667
# Name: fraud_reported, dtype: float64
# Target likelihood for insured_hobbies:
#
# insured_hobbies
# chess             0.785714
# cross-fit         0.750000
# base-jumping      0.375000
# board-games       0.352941
# yachting          0.333333
# video-games       0.307692
# paintball         0.285714
# skydiving         0.266667
# exercise          0.266667
# polo              0.235294
# movies            0.176471
# bungie-jumping    0.160000
# basketball        0.153846
# hiking            0.153846
# reading           0.153846
# sleeping          0.142857
# dancing           0.083333
# kayaking          0.083333
# golf              0.000000
# camping           0.000000
# Name: fraud_reported, dtype: float64
# Target likelihood for insured_relationship:
#
# insured_relationship
# wife              0.366667
# other-relative    0.322034
# not-in-family     0.258621
# husband           0.240741
# unmarried         0.222222
# own-child         0.156250
# Name: fraud_reported, dtype: float64
# Target likelihood for incident_type:
#
# incident_type
# Single Vehicle Collision    0.305970
# Multi-vehicle Collision     0.231884
# Parked Car                  0.200000
# Vehicle Theft               0.052632
# Name: fraud_reported, dtype: float64
# Target likelihood for collision_type:
#
# collision_type
# Rear Collision     0.282828
# Side Collision     0.274510
# Front Collision    0.239437
# ?                  0.103448
# Name: fraud_reported, dtype: float64
# Target likelihood for incident_severity:
#
# incident_severity
# Major Damage      0.575758
# Trivial Damage    0.157895
# Total Loss        0.117647
# Minor Damage      0.061224
# Name: fraud_reported, dtype: float64
# Target likelihood for authorities_contacted:
#
# authorities_contacted
# Other        0.321429
# Ambulance    0.300000
# Fire         0.253165
# Police       0.188679
# Name: fraud_reported, dtype: float64
# Target likelihood for incident_state:
#
# incident_state
# OH    0.600000
# VA    0.387097
# SC    0.309859
# PA    0.272727
# NY    0.234568
# NC    0.210526
# WV    0.140625
# Name: fraud_reported, dtype: float64
# Target likelihood for incident_city:
#
# incident_city
# Hillsdale      0.303030
# Northbrook     0.275000
# Columbus       0.270833
# Arlington      0.265306
# Springfield    0.238095
# Riverwood      0.216216
# Northbend      0.211538
# Name: fraud_reported, dtype: float64
# incident_city shows low variation in target likelihood: 0.09 -> Consider removing.
# Target likelihood for incident_location:
#
# incident_location
# 1353 Washington St    1.0
# 9942 Tree Ave         1.0
# 1030 Pine Lane        1.0
# 1472 4th Drive        1.0
# 1546 Cherokee Ave     1.0
#                      ...
# 1437 3rd Lane         0.0
# 1364 Best St          0.0
# 1358 Maple St         0.0
# 1091 1st Drive        0.0
# 1331 Elm Ridge        0.0
# Name: fraud_reported, Length: 301, dtype: float64
# Target likelihood for property_damage:
#
# property_damage
# ?      0.273585
# YES    0.260417
# NO     0.222222
# Name: fraud_reported, dtype: float64
# property_damage shows low variation in target likelihood: 0.05 -> Consider removing.
# Target likelihood for police_report_available:
#
# police_report_available
# NO     0.277311
# ?      0.265957
# YES    0.204545
# Name: fraud_reported, dtype: float64
# police_report_available shows low variation in target likelihood: 0.07 -> Consider removing.
# Target likelihood for auto_make:
#
# auto_make
# Mercedes      0.411765
# Ford          0.400000
# Volkswagen    0.333333
# Saab          0.304348
# Jeep          0.300000
# Audi          0.275862
# Chevrolet     0.250000
# BMW           0.227273
# Dodge         0.217391
# Nissan        0.192308
# Honda         0.176471
# Suburu        0.173913
# Toyota        0.173913
# Accura        0.071429
# Name: fraud_reported, dtype: float64
# Target likelihood for auto_model:
#
# auto_model
# M5                0.750000
# Escape            0.666667
# E400              0.666667
# Silverado         0.428571
# ML350             0.375000
# Grand Cherokee    0.363636
# F150              0.357143
# Maxima            0.333333
# Passat            0.333333
# C300              0.333333
# X6                0.333333
# 92x               0.333333
# A5                0.333333
# Jetta             0.333333
# 93                0.300000
# Tahoe             0.300000
# 95                0.285714
# CRV               0.250000
# Neon              0.222222
# Wrangler          0.222222
# RAM               0.214286
# A3                0.214286
# Corolla           0.200000
# Fusion            0.200000
# Legacy            0.200000
# Camry             0.166667
# Impreza           0.166667
# Highlander        0.166667
# MDX               0.142857
# Forrestor         0.142857
# Civic             0.142857
# Pathfinder        0.090909
# 3 Series          0.000000
# Accord            0.000000
# Malibu            0.000000
# TL                0.000000
# RSX               0.000000
# Ultima            0.000000
# X5                0.000000
# Name: fraud_reported, dtype: float64

# %%
print(weak_categorical_features)
X_train = X_train.drop(columns=weak_categorical_features)
X_val = X_val.drop(columns=weak_categorical_features)
# Out:
# ['policy_state', 'policy_csl', 'insured_sex', 'incident_city', 'property_damage', 'police_report_available']

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
for col in numerical_columns:
    plt.figure(figsize=(8, 4))
    sns.violinplot(x=y_train, y=X_train[col])
    plt.title(f'{col} ++++Distribution by Fraud Reported+++')
    plt.xlabel('++Fraud Reported++')
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
X_train_combined = X_train.copy()
y_train_combined = y_train.copy()

_ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = _ros.fit_resample(X_train_combined, y_train_combined)

# %%
resampled_distribution = pd.Series(y_train_resampled).value_counts()
resampled_distribution
# Out:
# fraud_reported
# 0    225
# 1    225
# Name: count, dtype: int64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data
X_train = X_train_resampled.copy()
y_train = y_train_resampled.copy()

# def categorize_umbrella(limit):
#     if limit == 0:
#         return 'No Umbrella'
#     elif limit <= 4000000:
#         return 'Low Umbrella'
#     else:
#         return 'High Umbrella'

#Claim ratios
X_train['injury_to_total_claim_ratio'] = X_train['injury_claim'] / (X_train['total_claim_amount'] + 1)
X_val['injury_to_total_claim_ratio'] = X_val['injury_claim'] / (X_val['total_claim_amount'] + 1)

X_train['property_to_total_claim_ratio'] = X_train['property_claim'] / (X_train['total_claim_amount'] + 1)
X_val['property_to_total_claim_ratio'] = X_val['property_claim'] / (X_val['total_claim_amount'] + 1)

X_train['vehicle_to_total_claim_ratio'] = X_train['vehicle_claim'] / (X_train['total_claim_amount'] + 1)
X_val['vehicle_to_total_claim_ratio'] = X_val['vehicle_claim'] / (X_val['total_claim_amount'] + 1)

#Interaction of age and deduction
X_train['age_times_policy_deductable'] = X_train['age'] * X_train['policy_deductable']
X_val['age_times_policy_deductable'] = X_val['age'] * X_val['policy_deductable']


# Claims per vehicle involved
X_train['claim_per_vehicle'] = X_train['total_claim_amount'] / (X_train['number_of_vehicles_involved'] + 1)
X_val['claim_per_vehicle'] = X_val['total_claim_amount'] / (X_val['number_of_vehicles_involved'] + 1)

# Create policy age in days
X_train['policy_age_days'] = (X_train['incident_date'] - X_train['policy_bind_date']).dt.days
X_val['policy_age_days'] = (X_val['incident_date'] - X_val['policy_bind_date']).dt.days

# Extract incident month and year
X_train['incident_month'] = X_train['incident_date'].dt.month
X_train['incident_year'] = X_train['incident_date'].dt.year

X_val['incident_month'] = X_val['incident_date'].dt.month
X_val['incident_year'] = X_val['incident_date'].dt.year

# Extract policy bind month and year
X_train['policy_bind_month'] = X_train['policy_bind_date'].dt.month
X_train['policy_bind_year'] = X_train['policy_bind_date'].dt.year

X_val['policy_bind_month'] = X_val['policy_bind_date'].dt.month
X_val['policy_bind_year'] = X_val['policy_bind_date'].dt.year

# Finally remove the original datetime columns from both datasets
X_train = X_train.drop(columns=['policy_bind_date', 'incident_date','umbrella_limit'], errors='ignore')
X_val = X_val.drop(columns=['policy_bind_date', 'incident_date','umbrella_limit'], errors='ignore')

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
threshold_corr = 0.75
upper_diag = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
to_drop_col = [column for column in upper_diag.columns if any(upper_diag[column] > threshold_corr)]
print(to_drop_col)
X_train = X_train.drop(columns=to_drop_col)
X_val = X_val.drop(columns=to_drop_col)
# Out:
# ['age', 'property_claim', 'vehicle_claim']

# %%
# Check the data
X_train.shape, X_val.shape
# Out:
# ((450, 35), (130, 35))

# %%
X_train.columns
# Out:
# Index(['months_as_customer', 'policy_deductable', 'policy_annual_premium',
#        'insured_zip', 'insured_education_level', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_location',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim',
#        'auto_make', 'auto_model', 'auto_year', 'injury_to_total_claim_ratio',
#        'property_to_total_claim_ratio', 'vehicle_to_total_claim_ratio',
#        'age_times_policy_deductable', 'claim_per_vehicle', 'policy_age_days',
#        'incident_month', 'incident_year', 'policy_bind_month',
#        'policy_bind_year'],
#       dtype='object')

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
eligible_for_frequency_grouping = ['collision_type',
    'authorities_contacted', 'incident_state'
]
def remap_rare_categories_by_frequency(df, column, min_count=20):
    freq = df[column].value_counts()
    rare_labels = freq[freq < min_count].index
    df[column] = df[column].apply(lambda x: 'Other' if x in rare_labels else x)
    return df

for col in eligible_for_frequency_grouping:
    if col in X_train.columns:
        X_train = remap_rare_categories_by_frequency(X_train, col, min_count=20)
        X_val = remap_rare_categories_by_frequency(X_val, col, min_count=20)


for col in X_train.select_dtypes(include='object').columns:
    X_train[col] = X_train[col].replace('?', 'Other')
    X_val[col] = X_val[col].replace('?', 'Other')


def frequency_encode(train_df, val_df, column):
    freq = train_df[column].value_counts()
    train_df[column + '_freq'] = train_df[column].map(freq)
    val_df[column + '_freq'] = val_df[column].map(freq).fillna(0)  # unseen in validation gets 0
    return train_df, val_df

# X_train, X_val = frequency_encode(X_train, X_val, 'incident_location')
X_train, X_val = frequency_encode(X_train, X_val, 'auto_model')
X_train = X_train.drop(columns=['incident_location', 'auto_model'])
X_val = X_val.drop(columns=['incident_location', 'auto_model'])

# %%
X_train.columns
# Out:
# Index(['months_as_customer', 'policy_deductable', 'policy_annual_premium',
#        'insured_zip', 'insured_education_level', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'auto_make', 'auto_year',
#        'injury_to_total_claim_ratio', 'property_to_total_claim_ratio',
#        'vehicle_to_total_claim_ratio', 'age_times_policy_deductable',
#        'claim_per_vehicle', 'policy_age_days', 'incident_month',
#        'incident_year', 'policy_bind_month', 'policy_bind_year',
#        'auto_model_freq'],
#       dtype='object')

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_columns = X_train.select_dtypes(include='object').columns
print(categorical_columns)
# Out:
# Index(['insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'auto_make'],
#       dtype='object')

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train_dummies = pd.get_dummies(X_train, columns=categorical_columns, drop_first=True).astype(float)
X_train_dummies = X_train_dummies.astype(int)
X_train_dummies.shape
# Out:
# (450, 97)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_val_dummies = pd.get_dummies(X_val, columns=categorical_columns, drop_first=True).astype(float)
X_val_dummies = X_val_dummies.reindex(columns=X_train_dummies.columns, fill_value=0)
X_val_dummies = X_val_dummies.astype(int)
X_val_dummies.shape
# Out:
# (130, 97)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
# already done in above cell
y_train_dummies = y_train.copy()
# Create dummy variable for dependent feature in validation data
y_val_dummies = y_val.copy()

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler
# Scale the numeric features present in the training data
numerical_columns = X_train_dummies.select_dtypes(include=['int64', 'float64']).columns
print(numerical_columns)
# Scale the numeric features present in the validation data
scaler = StandardScaler()
X_train_dummies[numerical_columns] = scaler.fit_transform(X_train_dummies[numerical_columns])
X_val_dummies[numerical_columns] = scaler.transform(X_val_dummies[numerical_columns])

X_train_dummies.shape, X_val_dummies.shape
# Out:
# Index(['months_as_customer', 'policy_deductable', 'policy_annual_premium',
#        'insured_zip', 'capital-gains', 'capital-loss',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim',
#        'auto_year', 'injury_to_total_claim_ratio',
#        'property_to_total_claim_ratio', 'vehicle_to_total_claim_ratio',
#        'age_times_policy_deductable', 'claim_per_vehicle', 'policy_age_days',
#        'incident_month', 'incident_year', 'policy_bind_month',
#        'policy_bind_year', 'auto_model_freq',
#        'insured_education_level_College',
#        'insured_education_level_High School', 'insured_education_level_JD',
#        'insured_education_level_MD', 'insured_education_level_Masters',
#        'insured_education_level_PhD', 'insured_occupation_armed-forces',
#        'insured_occupation_craft-repair', 'insured_occupation_exec-managerial',
#        'insured_occupation_farming-fishing',
#        'insured_occupation_handlers-cleaners',
#        'insured_occupation_machine-op-inspct',
#        'insured_occupation_other-service',
#        'insured_occupation_priv-house-serv',
#        'insured_occupation_prof-specialty',
#        'insured_occupation_protective-serv', 'insured_occupation_sales',
#        'insured_occupation_tech-support',
#        'insured_occupation_transport-moving', 'insured_hobbies_basketball',
#        'insured_hobbies_board-games', 'insured_hobbies_bungie-jumping',
#        'insured_hobbies_camping', 'insured_hobbies_chess',
#        'insured_hobbies_cross-fit', 'insured_hobbies_dancing',
#        'insured_hobbies_exercise', 'insured_hobbies_golf',
#        'insured_hobbies_hiking', 'insured_hobbies_kayaking',
#        'insured_hobbies_movies', 'insured_hobbies_paintball',
#        'insured_hobbies_polo', 'insured_hobbies_reading',
#        'insured_hobbies_skydiving', 'insured_hobbies_sleeping',
#        'insured_hobbies_video-games', 'insured_hobbies_yachting',
#        'insured_relationship_not-in-family',
#        'insured_relationship_other-relative', 'insured_relationship_own-child',
#        'insured_relationship_unmarried', 'insured_relationship_wife',
#        'incident_type_Parked Car', 'incident_type_Single Vehicle Collision',
#        'incident_type_Vehicle Theft', 'collision_type_Other',
#        'collision_type_Rear Collision', 'collision_type_Side Collision',
#        'incident_severity_Minor Damage', 'incident_severity_Total Loss',
#        'incident_severity_Trivial Damage', 'authorities_contacted_Fire',
#        'authorities_contacted_Other', 'authorities_contacted_Police',
#        'incident_state_NY', 'incident_state_Other', 'incident_state_SC',
#        'incident_state_VA', 'incident_state_WV', 'auto_make_Audi',
#        'auto_make_BMW', 'auto_make_Chevrolet', 'auto_make_Dodge',
#        'auto_make_Ford', 'auto_make_Honda', 'auto_make_Jeep',
#        'auto_make_Mercedes', 'auto_make_Nissan', 'auto_make_Saab',
#        'auto_make_Suburu', 'auto_make_Toyota', 'auto_make_Volkswagen'],
#       dtype='object')
# ((450, 97), (130, 97))

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Apply RFECV to identify the most relevant features
log_reg_model = LogisticRegression( solver='liblinear', random_state=42)
rfecv = RFECV(
    estimator=log_reg_model,
    step=1,
    cv=StratifiedKFold(5),
    scoring='accuracy',
    n_jobs=-1
)
rfecv.fit(X_train_dummies, y_train)
selected_features = X_train_dummies.columns[rfecv.support_]
print(selected_features)
# Out:
# Index(['policy_annual_premium', 'incident_hour_of_the_day', 'injury_claim',
#        'auto_year', 'claim_per_vehicle', 'incident_month', 'policy_bind_month',
#        'auto_model_freq', 'insured_education_level_College',
#        'insured_education_level_High School', 'insured_education_level_JD',
#        'insured_education_level_Masters', 'insured_occupation_armed-forces',
#        'insured_occupation_craft-repair', 'insured_occupation_farming-fishing',
#        'insured_occupation_machine-op-inspct',
#        'insured_occupation_other-service',
#        'insured_occupation_priv-house-serv',
#        'insured_occupation_protective-serv', 'insured_occupation_sales',
#        'insured_hobbies_basketball', 'insured_hobbies_board-games',
#        'insured_hobbies_camping', 'insured_hobbies_chess',
#        'insured_hobbies_cross-fit', 'insured_hobbies_exercise',
#        'insured_hobbies_golf', 'insured_hobbies_kayaking',
#        'insured_hobbies_movies', 'insured_hobbies_paintball',
#        'insured_hobbies_polo', 'insured_hobbies_reading',
#        'insured_hobbies_sleeping', 'insured_relationship_own-child',
#        'collision_type_Other', 'collision_type_Side Collision',
#        'incident_severity_Minor Damage', 'incident_severity_Total Loss',
#        'incident_severity_Trivial Damage', 'incident_state_SC',
#        'incident_state_VA', 'incident_state_WV', 'auto_make_BMW',
#        'auto_make_Jeep', 'auto_make_Nissan', 'auto_make_Suburu',
#        'auto_make_Toyota', 'auto_make_Volkswagen'],
#       dtype='object')

# %%
# Display the features ranking by RFECV in a DataFrame
feature_ranking_df = pd.DataFrame({
    'Feature': X_train_dummies.columns,
    'Ranking': rfecv.ranking_,
    'Selected': rfecv.support_
}).sort_values(by='Ranking')

feature_ranking_df.head(20)
# Out:
#                                 Feature  Ranking  Selected
# 2                 policy_annual_premium        1      True
# 6              incident_hour_of_the_day        1      True
# 12                            auto_year        1      True
# 11                         injury_claim        1      True
# 21                    policy_bind_month        1      True
# 23                      auto_model_freq        1      True
# 30      insured_occupation_armed-forces        1      True
# 31      insured_occupation_craft-repair        1      True
# 24      insured_education_level_College        1      True
# 25  insured_education_level_High School        1      True
# 26           insured_education_level_JD        1      True
# 28      insured_education_level_Masters        1      True
# 19                       incident_month        1      True
# 17                    claim_per_vehicle        1      True
# 56                 insured_hobbies_polo        1      True
# 59             insured_hobbies_sleeping        1      True
# 48            insured_hobbies_cross-fit        1      True
# 50             insured_hobbies_exercise        1      True
# 51                 insured_hobbies_golf        1      True
# 53             insured_hobbies_kayaking        1      True

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = selected_features.tolist()
col
# Out:
# ['policy_annual_premium',
#  'incident_hour_of_the_day',
#  'injury_claim',
#  'auto_year',
#  'claim_per_vehicle',
#  'incident_month',
#  'policy_bind_month',
#  'auto_model_freq',
#  'insured_education_level_College',
#  'insured_education_level_High School',
#  'insured_education_level_JD',
#  'insured_education_level_Masters',
#  'insured_occupation_armed-forces',
#  'insured_occupation_craft-repair',
#  'insured_occupation_farming-fishing',
#  'insured_occupation_machine-op-inspct',
#  'insured_occupation_other-service',
#  'insured_occupation_priv-house-serv',
#  'insured_occupation_protective-serv',
#  'insured_occupation_sales',
#  'insured_hobbies_basketball',
#  'insured_hobbies_board-games',
#  'insured_hobbies_camping',
#  'insured_hobbies_chess',
#  'insured_hobbies_cross-fit',
#  'insured_hobbies_exercise',
#  'insured_hobbies_golf',
#  'insured_hobbies_kayaking',
#  'insured_hobbies_movies',
#  'insured_hobbies_paintball',
#  'insured_hobbies_polo',
#  'insured_hobbies_reading',
#  'insured_hobbies_sleeping',
#  'insured_relationship_own-child',
#  'collision_type_Other',
#  'collision_type_Side Collision',
#  'incident_severity_Minor Damage',
#  'incident_severity_Total Loss',
#  'incident_severity_Trivial Damage',
#  'incident_state_SC',
#  'incident_state_VA',
#  'incident_state_WV',
#  'auto_make_BMW',
#  'auto_make_Jeep',
#  'auto_make_Nissan',
#  'auto_make_Suburu',
#  'auto_make_Toyota',
#  'auto_make_Volkswagen']

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
columns_to_remove = [
    'insured_education_level_College',  # Drop one of education level
    'insured_hobbies_basketball',       # Drop one of hobbies
    'collision_type_Other',             # Drop one of collision type
    'incident_severity_Minor Damage',   # Drop one of severity
    'incident_state_SC',                # Drop one of states
    'auto_make_BMW'                     # Drop one of auto_make
]

# %%
# Select only the columns selected by RFECV
X_train_rfecv = X_train_dummies[col]
X_val_rfecv = X_val_dummies[col]
X_train_rfecv = X_train_rfecv.drop(columns=columns_to_remove)
X_val_rfecv = X_val_rfecv.drop(columns=columns_to_remove)
print("X_train after RFECV feature selection:", X_train_rfecv.shape)
print("X_val after RFECV feature selection:", X_val_rfecv.shape)
# Out:
# X_train after RFECV feature selection: (450, 42)
# X_val after RFECV feature selection: (130, 42)

# %%
# Import statsmodels and add constant
import statsmodels.api as sm
X_train_rfecv_sm = sm.add_constant(X_train_rfecv)
X_const = X_train_rfecv_sm.astype(float)
# Check the data
X_train_rfecv_sm.head()
# Out:
#    const  policy_annual_premium  incident_hour_of_the_day  injury_claim  \
# 0    1.0               0.631459                  1.423575     -0.469937
# 1    1.0               0.217320                  1.714562     -0.451756
# 2    1.0               0.672463                  0.550613      0.727693
# 3    1.0               1.804168                  0.987094      0.182283
# 4    1.0               0.725768                  0.841600     -0.351764
#
#    auto_year  claim_per_vehicle  incident_month  policy_bind_month  \
# 0  -0.787747           0.505379       -0.873132           0.460837
# 1  -0.626617          -0.852644       -0.873132           0.179075
# 2  -0.304357          -0.558498       -0.873132          -0.102687
# 3  -0.626617          -0.870130        1.034195           1.024362
# 4  -1.593396           0.458201       -0.873132          -0.666211
#
#    auto_model_freq  insured_education_level_High School  ...  \
# 0         1.204337                             -0.45435  ...
# 1         1.385108                             -0.45435  ...
# 2         1.204337                             -0.45435  ...
# 3        -0.422603                             -0.45435  ...
# 4         1.565879                             -0.45435  ...
#
#    collision_type_Side Collision  incident_severity_Total Loss  \
# 0                       1.359449                      1.812654
# 1                       1.359449                     -0.551677
# 2                      -0.735592                     -0.551677
# 3                      -0.735592                      1.812654
# 4                      -0.735592                      1.812654
#
#    incident_severity_Trivial Damage  incident_state_VA  incident_state_WV  \
# 0                          -0.22672           -0.36146          -0.440039
# 1                          -0.22672           -0.36146          -0.440039
# 2                          -0.22672           -0.36146          -0.440039
# 3                          -0.22672           -0.36146          -0.440039
# 4                          -0.22672           -0.36146          -0.440039
#
#    auto_make_Jeep  auto_make_Nissan  auto_make_Suburu  auto_make_Toyota  \
# 0       -0.252646          3.292735         -0.276686         -0.281312
# 1       -0.252646         -0.303699         -0.276686         -0.281312
# 2       -0.252646          3.292735         -0.276686         -0.281312
# 3       -0.252646         -0.303699         -0.276686         -0.281312
# 4       -0.252646         -0.303699         -0.276686         -0.281312
#
#    auto_make_Volkswagen
# 0             -0.267261
# 1             -0.267261
# 2             -0.267261
# 3              3.741657
# 4             -0.267261
#
# [5 rows x 43 columns]

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
logit_model = sm.Logit(y_train, X_train_rfecv_sm)
result = logit_model.fit()
print(result.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.355792
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  450
# Model:                          Logit   Df Residuals:                      407
# Method:                           MLE   Df Model:                           42
# Date:                Sun, 18 May 2025   Pseudo R-squ.:                  0.4867
# Time:                        07:44:40   Log-Likelihood:                -160.11
# converged:                      False   LL-Null:                       -311.92
# Covariance Type:            nonrobust   LLR p-value:                 2.347e-41
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                   -1.7183   2.17e+04  -7.92e-05      1.000   -4.25e+04    4.25e+04
# policy_annual_premium                   -0.3189      0.164     -1.942      0.052      -0.641       0.003
# incident_hour_of_the_day                -0.4581      0.161     -2.838      0.005      -0.774      -0.142
# injury_claim                            -0.3830      0.192     -1.990      0.047      -0.760      -0.006
# auto_year                               -0.1301      0.172     -0.759      0.448      -0.466       0.206
# claim_per_vehicle                        0.8801      0.205      4.293      0.000       0.478       1.282
# incident_month                          -0.4648      0.168     -2.772      0.006      -0.793      -0.136
# policy_bind_month                        0.3187      0.160      1.993      0.046       0.005       0.632
# auto_model_freq                          0.9051      0.181      5.002      0.000       0.550       1.260
# insured_education_level_High School     -0.4224      0.204     -2.073      0.038      -0.822      -0.023
# insured_education_level_JD               0.3385      0.188      1.800      0.072      -0.030       0.707
# insured_education_level_Masters         -0.1758      0.158     -1.115      0.265      -0.485       0.133
# insured_occupation_armed-forces         -0.0483      0.157     -0.307      0.759      -0.357       0.260
# insured_occupation_craft-repair         -0.0849      0.166     -0.512      0.609      -0.410       0.240
# insured_occupation_farming-fishing       0.0785      0.184      0.427      0.670      -0.282       0.439
# insured_occupation_machine-op-inspct     0.0271      0.178      0.152      0.879      -0.321       0.375
# insured_occupation_other-service        -0.3733      0.164     -2.273      0.023      -0.695      -0.051
# insured_occupation_priv-house-serv      -0.4051      0.202     -2.007      0.045      -0.801      -0.010
# insured_occupation_protective-serv      -0.8079      0.189     -4.267      0.000      -1.179      -0.437
# insured_occupation_sales                -0.1843      0.152     -1.215      0.225      -0.482       0.113
# insured_hobbies_board-games              0.4015      0.178      2.260      0.024       0.053       0.750
# insured_hobbies_camping                 -5.0711   4.19e+04     -0.000      1.000   -8.21e+04    8.21e+04
# insured_hobbies_chess                    1.0150      0.231      4.394      0.000       0.562       1.468
# insured_hobbies_cross-fit                1.0260      0.215      4.767      0.000       0.604       1.448
# insured_hobbies_exercise                 0.0881      0.150      0.589      0.556      -0.205       0.381
# insured_hobbies_golf                    -5.1958   1.17e+05  -4.43e-05      1.000    -2.3e+05     2.3e+05
# insured_hobbies_kayaking                -0.3757      0.163     -2.308      0.021      -0.695      -0.057
# insured_hobbies_movies                  -0.3985      0.176     -2.258      0.024      -0.744      -0.053
# insured_hobbies_paintball                0.0037      0.131      0.029      0.977      -0.253       0.260
# insured_hobbies_polo                    -0.0339      0.158     -0.214      0.830      -0.344       0.276
# insured_hobbies_reading                 -0.2022      0.161     -1.256      0.209      -0.518       0.113
# insured_hobbies_sleeping                -0.3140      0.158     -1.984      0.047      -0.624      -0.004
# insured_relationship_own-child          -0.0440      0.164     -0.268      0.788      -0.365       0.277
# collision_type_Side Collision           -0.3378      0.178     -1.896      0.058      -0.687       0.011
# incident_severity_Total Loss            -1.4250      0.218     -6.545      0.000      -1.852      -0.998
# incident_severity_Trivial Damage        -0.3002      0.196     -1.533      0.125      -0.684       0.084
# incident_state_VA                        0.4371      0.167      2.622      0.009       0.110       0.764
# incident_state_WV                       -0.2063      0.166     -1.242      0.214      -0.532       0.119
# auto_make_Jeep                           0.0015      0.131      0.011      0.991      -0.255       0.258
# auto_make_Nissan                        -0.4750      0.182     -2.608      0.009      -0.832      -0.118
# auto_make_Suburu                        -0.3279      0.158     -2.077      0.038      -0.637      -0.018
# auto_make_Toyota                        -0.2015      0.162     -1.246      0.213      -0.519       0.116
# auto_make_Volkswagen                     0.3175      0.198      1.605      0.108      -0.070       0.705
# ========================================================================================================

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
vif_data = pd.DataFrame()
vif_data["Feature"] = X_train_rfecv_sm.columns
vif_data["VIF"] = [variance_inflation_factor(X_train_rfecv_sm.values, i) for i in range(X_train_rfecv_sm.shape[1])]
vif_data_sorted = vif_data.sort_values(by='VIF', ascending=False)
vif_data_sorted.head(10)
# Out:
#                                  Feature       VIF
# 5                      claim_per_vehicle  1.771743
# 3                           injury_claim  1.670132
# 10            insured_education_level_JD  1.562394
# 35      incident_severity_Trivial Damage  1.544304
# 9    insured_education_level_High School  1.472994
# 13       insured_occupation_craft-repair  1.428079
# 22                 insured_hobbies_chess  1.421717
# 14    insured_occupation_farming-fishing  1.400850
# 30               insured_hobbies_reading  1.379830
# 15  insured_occupation_machine-op-inspct  1.368599

# %%
#droping the features having high VIF
high_vif_features = vif_data_sorted[vif_data_sorted['VIF'] > 5]['Feature'].tolist()
high_vif_features
# Out:
# []

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
y_train_pred_prob = result.predict(X_train_rfecv_sm)

# Display first few predicted probabilities
# print(y_train_pred_prob.head())
# Reshape it into an array
y_train_pred_prob_array = y_train_pred_prob.values.reshape(-1)
# print(y_train_pred_prob_array)

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
predictions_df = pd.DataFrame({
    'Actual': y_train,
    'Predicted_Prob': y_train_pred_prob_array,
    'Predicted_Class': (y_train_pred_prob_array >= 0.5).astype(int)
})
# Create new column indicating predicted classifications based on a cutoff value of 0.5
predictions_df.head()
# Out:
#    Actual  Predicted_Prob  Predicted_Class
# 0       0        0.000313                0
# 1       1        0.992677                1
# 2       0        0.720957                1
# 3       0        0.028089                0
# 4       0        0.492664                0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
accuracy = metrics.accuracy_score(predictions_df['Actual'], predictions_df['Predicted_Class'])
print(f"Accuracy of the model on the training data: {accuracy}")
# Out:
# Accuracy of the model on the training data: 0.8511111111111112

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(predictions_df['Actual'], predictions_df['Predicted_Class'])

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[182  43]
#  [ 24 201]]

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
# Extract TP, TN, FP, FN from confusion matrix
tn, fp, fn, tp = metrics.confusion_matrix(predictions_df['Actual'], predictions_df['Predicted_Class']).ravel()

# Display the values
print(f"True Positive (TP): {tp}")
print(f"True Negative (TN): {tn}")
print(f"False Positive (FP): {fp}")
print(f"False Negative (FN): {fn}")
# Out:
# True Positive (TP): 201
# True Negative (TN): 182
# False Positive (FP): 43
# False Negative (FN): 24

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)

# Calculate the specificity
specificity = tn / (tn + fp)

# Calculate Precision
precision = tp / (tp + fp)

# Calculate Recall
recall = sensitivity

# Calculate F1 Score
f1_score = metrics.f1_score(predictions_df['Actual'], predictions_df['Predicted_Class'])

print(f"Sensitivity (Recall): {sensitivity}")
print(f"Specificity: {specificity}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
# Out:
# Sensitivity (Recall): 0.8933333333333333
# Specificity: 0.8088888888888889
# Precision: 0.8237704918032787
# Recall: 0.8933333333333333
# F1 Score: 0.8571428571428571

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, auc

# Define ROC function
def plot_roc_curve(y_true, y_pred_prob):
    """
    ROC curve and calculates AUC.
    """
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate (1 - Specificity)')
    plt.ylabel('True Positive Rate (Sensitivity)')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

# %%
# Call the ROC function
plot_roc_curve(predictions_df['Actual'], predictions_df['Predicted_Prob'])

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
cutoff_values = [0.3, 0.4, 0.5, 0.6, 0.7]
for cutoff in cutoff_values:
    predictions_df[f'Predicted_Class_{cutoff}'] = (predictions_df['Predicted_Prob'] >= cutoff).astype(int)
predictions_df.head()
# Out:
#    Actual  Predicted_Prob  Predicted_Class  Predicted_Class_0.3  \
# 0       0        0.000313                0                    0
# 1       1        0.992677                1                    1
# 2       0        0.720957                1                    1
# 3       0        0.028089                0                    0
# 4       0        0.492664                0                    1
#
#    Predicted_Class_0.4  Predicted_Class_0.5  Predicted_Class_0.6  \
# 0                    0                    0                    0
# 1                    1                    1                    1
# 2                    1                    1                    1
# 3                    0                    0                    0
# 4                    1                    0                    0
#
#    Predicted_Class_0.7
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    0

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
def calculate_metrics(y_true, y_prob, cutoff):
    y_pred = (y_prob >= cutoff).astype(int)
    tn, fp, fn, tp = metrics.confusion_matrix(y_true, y_pred).ravel()
    accuracy = metrics.accuracy_score(y_true, y_pred)
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    return accuracy, sensitivity, specificity


metrics_list = []
for cutoff in cutoff_values:
    acc, sens, spec = calculate_metrics(predictions_df['Actual'], predictions_df['Predicted_Prob'], cutoff)
    metrics_list.append({'Cutoff': cutoff, 'Accuracy': acc, 'Sensitivity': sens, 'Specificity': spec})

cutoff_metrics_df = pd.DataFrame(metrics_list)
cutoff_metrics_df.head()
# Out:
#    Cutoff  Accuracy  Sensitivity  Specificity
# 0     0.3  0.840000     0.968889     0.711111
# 1     0.4  0.835556     0.915556     0.755556
# 2     0.5  0.851111     0.893333     0.808889
# 3     0.6  0.811111     0.768889     0.853333
# 4     0.7  0.797778     0.693333     0.902222

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(6,4))
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Accuracy'], label='Accuracy')
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Sensitivity'], label='Sensitivity (Recall)')
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Specificity'], label='Specificity')
plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.title('Accuracy, Sensitivity, and Specificity at Different Cutoff Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
optimal_cutoff = 0.40

# Create the final prediction column based on the optimal cutoff
predictions_df['Final_Prediction'] = (predictions_df['Predicted_Prob'] >= optimal_cutoff).astype(int)

predictions_df[['Actual', 'Predicted_Prob', 'Final_Prediction']].head()
# Out:
#    Actual  Predicted_Prob  Final_Prediction
# 0       0        0.000313                 0
# 1       1        0.992677                 1
# 2       0        0.720957                 1
# 3       0        0.028089                 0
# 4       0        0.492664                 1

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
accuracy_optimal = metrics.accuracy_score(predictions_df['Actual'], predictions_df['Final_Prediction'])
print(f"Accuracy of the model at the optimal cutoff ({optimal_cutoff}): {accuracy_optimal}")
# Out:
# Accuracy of the model at the optimal cutoff (0.4): 0.8355555555555556

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
conf_matrix_optimal = metrics.confusion_matrix(predictions_df['Actual'], predictions_df['Final_Prediction'])
print(conf_matrix_optimal)
# Out:
# [[170  55]
#  [ 19 206]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_opt, fp_opt, fn_opt, tp_opt = metrics.confusion_matrix(predictions_df['Actual'], predictions_df['Final_Prediction']).ravel()
print(f"True Positive (TP): {tp_opt}")
print(f"True Negative (TN): {tn_opt}")
print(f"False Positive (FP): {fp_opt}")
print(f"False Negative (FN): {fn_opt}")
# Out:
# True Positive (TP): 206
# True Negative (TN): 170
# False Positive (FP): 55
# False Negative (FN): 19

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity_opt = tp_opt / (tp_opt + fn_opt) if (tp_opt + fn_opt) > 0 else 0
# Calculate the specificity
specificity_opt = tn_opt / (tn_opt + fp_opt) if (tn_opt + fp_opt) > 0 else 0
# Calculate Precision
precision_opt = tp_opt / (tp_opt + fp_opt) if (tp_opt + fp_opt) > 0 else 0
# Calculate Recall
recall_opt = sensitivity_opt
# Calculate F1 Score
f1_score_opt = metrics.f1_score(predictions_df['Actual'], predictions_df['Final_Prediction'])

print(f"Sensitivity (Recall): {sensitivity_opt:.4f}")
print(f"Specificity: {specificity_opt:.4f}")
print(f"Precision: {precision_opt:.4f}")
print(f"Recall: {recall_opt:.4f}")
print(f"F1 Score: {f1_score_opt:.4f}")
# Out:
# Sensitivity (Recall): 0.9156
# Specificity: 0.7556
# Precision: 0.7893
# Recall: 0.9156
# F1 Score: 0.8477

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
from sklearn.metrics import precision_recall_curve, average_precision_score
precision, recall, thresholds_pr = precision_recall_curve(predictions_df['Actual'], predictions_df['Predicted_Prob'])
average_precision = average_precision_score(predictions_df['Actual'], predictions_df['Predicted_Prob'])
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f'Precision-Recall Curve (AP = {average_precision:.4f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_rfecv, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
rf_feature_importance = pd.DataFrame({
    'Feature': X_train_rfecv.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)
# Create a DataFrame to visualise the importance scores
rf_feature_importance.head(10)
# Out:
#                          Feature  Importance
# 4              claim_per_vehicle    0.126261
# 7                auto_model_freq    0.095906
# 1       incident_hour_of_the_day    0.078594
# 0          policy_annual_premium    0.078175
# 2                   injury_claim    0.076165
# 3                      auto_year    0.065731
# 6              policy_bind_month    0.064240
# 33  incident_severity_Total Loss    0.044812
# 21         insured_hobbies_chess    0.036756
# 22     insured_hobbies_cross-fit    0.031755

# %%
# Select features with high importance scores
importance_threshold = 0.05
high_importance_features = rf_feature_importance[rf_feature_importance['Importance'] > importance_threshold]['Feature'].tolist()
print(f"Selected high importance features (Importance > {importance_threshold}):\n{high_importance_features}")
# Create a new training data with only the selected features
X_train_rf_selected = X_train_rfecv[high_importance_features]
X_val_rf_selected = X_val_rfecv[high_importance_features]
# Out:
# Selected high importance features (Importance > 0.05):
# ['claim_per_vehicle', 'auto_model_freq', 'incident_hour_of_the_day', 'policy_annual_premium', 'injury_claim', 'auto_year', 'policy_bind_month']

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_model_selected = RandomForestClassifier(random_state=42)
rf_model_selected.fit(X_train_rf_selected, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_rf_pred_selected = rf_model_selected.predict(X_train_rf_selected)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
from sklearn.metrics import accuracy_score
rf_train_accuracy_selected = accuracy_score(y_train, y_train_rf_pred_selected)
rf_train_accuracy_selected
# Out:
# 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
from sklearn.metrics import confusion_matrix
conf_matrix_rf_selected = confusion_matrix(y_train, y_train_rf_pred_selected)
print("Confusion Matrix (Random Forest with selected features):")
print(conf_matrix_rf_selected)
# Out:
# Confusion Matrix (Random Forest with selected features):
# [[225   0]
#  [  0 225]]

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_rf, fp_rf, fn_rf, tp_rf = confusion_matrix(y_train, y_train_rf_pred_selected).ravel()
print(f"True Positive (TP): {tp_rf}")
print(f"True Negative (TN): {tn_rf}")
print(f"False Positive (FP): {fp_rf}")
print(f"False Negative (FN): {fn_rf}")
# Out:
# True Positive (TP): 225
# True Negative (TN): 225
# False Positive (FP): 0
# False Negative (FN): 0

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf = tp_rf / (tp_rf + fn_rf) if (tp_rf + fn_rf) > 0 else 0

# Calculate the specificity
specificity_rf = tn_rf / (tn_rf + fp_rf) if (tn_rf + fp_rf) > 0 else 0


# Calculate Precision
precision_rf = tp_rf / (tp_rf + fp_rf) if (tp_rf + fp_rf) > 0 else 0


# Calculate Recall
recall_rf = sensitivity_rf


# Calculate F1 Score
f1_score_rf = metrics.f1_score(y_train, y_train_rf_pred_selected)

print(f"Sensitivity (Recall): {sensitivity_rf:.4f}")
print(f"Specificity: {specificity_rf:.4f}")
print(f"Precision: {precision_rf:.4f}")
print(f"Recall: {recall_rf:.4f}")
print(f"F1 Score: {f1_score_rf:.4f}")
# Out:
# Sensitivity (Recall): 1.0000
# Specificity: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(rf_model_selected, X_train_rf_selected, y_train, cv=5, scoring='accuracy')
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean CV accuracy: {cv_scores.mean():.4f}")
print(f"Training accuracy: {rf_train_accuracy_selected:.4f}")
# Out:
# Cross-validation scores: [0.87777778 0.88888889 0.88888889 0.94444444 0.93333333]
# Mean CV accuracy: 0.9067
# Training accuracy: 1.0000

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}
rf_model_grid = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf_model_grid, param_grid=param_grid,
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=1)
grid_search.fit(X_train_rf_selected, y_train)


# Best Hyperparameters
print("Best Hyperparameters:")
print(grid_search.best_params_)

best_rf_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best Hyperparameters:
# {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_model_tuned = RandomForestClassifier(
    n_estimators=grid_search.best_params_['n_estimators'],
    max_depth=grid_search.best_params_['max_depth'],
    min_samples_split=grid_search.best_params_['min_samples_split'],
    min_samples_leaf=grid_search.best_params_['min_samples_leaf'],
    max_features=grid_search.best_params_['max_features'],
    random_state=42
)

rf_model_tuned.fit(X_train_rf_selected, y_train)
# Out:
# RandomForestClassifier(max_depth=15, random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
y_train_rf_tuned_pred = rf_model_tuned.predict(X_train_rf_selected)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
rf_train_accuracy_tuned = accuracy_score(y_train, y_train_rf_tuned_pred)
print(f"Random Forest Training Accuracy (Tuned Model): {rf_train_accuracy_tuned}")
# Out:
# Random Forest Training Accuracy (Tuned Model): 1.0

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_rf_tuned = confusion_matrix(y_train, y_train_rf_tuned_pred)
conf_matrix_rf_tuned
# Out:
# array([[225,   0],
#        [  0, 225]])

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_rf_tuned, fp_rf_tuned, fn_rf_tuned, tp_rf_tuned = confusion_matrix(y_train, y_train_rf_tuned_pred).ravel()

print(f"True Positive (TP): {tp_rf_tuned}")
print(f"True Negative (TN): {tn_rf_tuned}")
print(f"False Positive (FP): {fp_rf_tuned}")
print(f"False Negative (FN): {fn_rf_tuned}")
# Out:
# True Positive (TP): 225
# True Negative (TN): 225
# False Positive (FP): 0
# False Negative (FN): 0

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf_tuned = tp_rf_tuned / (tp_rf_tuned + fn_rf_tuned) if (tp_rf_tuned + fn_rf_tuned) > 0 else 0
# Calculate the specificity
specificity_rf_tuned = tn_rf_tuned / (tn_rf_tuned + fp_rf_tuned) if (tn_rf_tuned + fp_rf_tuned) > 0 else 0
# Calculate Precision
precision_rf_tuned = tp_rf_tuned / (tp_rf_tuned + fp_rf_tuned) if (tp_rf_tuned + fp_rf_tuned) > 0 else 0
# Calculate Recall
recall_rf_tuned = sensitivity_rf_tuned
# Calculate F1-Score
f1_score_rf_tuned = metrics.f1_score(y_train, y_train_rf_tuned_pred)
print(f"Sensitivity (Recall): {sensitivity_rf_tuned:.4f}")
print(f"Specificity: {specificity_rf_tuned:.4f}")
print(f"Precision: {precision_rf_tuned:.4f}")
print(f"Recall: {recall_rf_tuned:.4f}")
print(f"F1 Score: {f1_score_rf_tuned:.4f}")
# Out:
# Sensitivity (Recall): 1.0000
# Specificity: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_val_rfecv_sm = sm.add_constant(X_val_rfecv)
X_const = X_val_rfecv_sm.astype(float)
# Check the data
X_val_rfecv_sm.head()

logit_model = sm.Logit(y_val_dummies, X_val_rfecv)
result = logit_model.fit()
# print(result.summary())

vif_data = pd.DataFrame()
vif_data["Feature"] = X_val_rfecv_sm.columns
vif_data["VIF"] = [variance_inflation_factor(X_val_rfecv_sm.values, i) for i in range(X_val_rfecv_sm.shape[1])]
vif_data_sorted = vif_data.sort_values(by='VIF', ascending=False)
vif_data_sorted.head(10)

high_vif_features = vif_data_sorted[vif_data_sorted['VIF'] > 5]['Feature'].tolist()
high_vif_features
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.398432
#          Iterations: 35
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# []

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
y_validation_pred = result.predict(X_val_rfecv_sm)
y_validation_pred_prob_array = y_validation_pred.values.reshape(-1)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
predictions_df_val = pd.DataFrame({
    'Actual': y_val,
    'Predicted_Prob': y_validation_pred_prob_array,
    'Predicted_Class': (y_validation_pred_prob_array >= 0.5).astype(int)
})
predictions_df_val.head()
# Out:
#    Actual  Predicted_Prob  Predicted_Class
# 0       0    9.416840e-02                0
# 1       0    1.731861e-01                0
# 2       0    2.360402e-09                0
# 3       0    2.696421e-01                0
# 4       1    6.398470e-01                1

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
optimal_cutoff = 0.40
predictions_df_val['Final_Prediction'] = (predictions_df_val['Predicted_Prob'] >= optimal_cutoff).astype(int)
predictions_df_val[['Actual', 'Predicted_Prob', 'Final_Prediction']].head()
# Out:
#    Actual  Predicted_Prob  Final_Prediction
# 0       0    9.416840e-02                 0
# 1       0    1.731861e-01                 0
# 2       0    2.360402e-09                 0
# 3       0    2.696421e-01                 0
# 4       1    6.398470e-01                 1

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
accuracy_optimal = metrics.accuracy_score(predictions_df_val['Actual'], predictions_df_val['Final_Prediction'])
print(f"Accuracy of the model at the optimal cutoff ({optimal_cutoff}): {accuracy_optimal}")
# Out:
# Accuracy of the model at the optimal cutoff (0.4): 0.8

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_optimal = metrics.confusion_matrix(predictions_df_val['Actual'], predictions_df_val['Final_Prediction'])
print(conf_matrix_optimal)
# Out:
# [[82 15]
#  [11 22]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_opt, fp_opt, fn_opt, tp_opt = metrics.confusion_matrix(predictions_df_val['Actual'], predictions_df_val['Final_Prediction']).ravel()
print(f"True Positive (TP): {tp_opt}")
print(f"True Negative (TN): {tn_opt}")
print(f"False Positive (FP): {fp_opt}")
print(f"False Negative (FN): {fn_opt}")
# Out:
# True Positive (TP): 22
# True Negative (TN): 82
# False Positive (FP): 15
# False Negative (FN): 11

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_opt = tp_opt / (tp_opt + fn_opt) if (tp_opt + fn_opt) > 0 else 0
# Calculate the specificity
specificity_opt = tn_opt / (tn_opt + fp_opt) if (tn_opt + fp_opt) > 0 else 0
# Calculate Precision
precision_opt = tp_opt / (tp_opt + fp_opt) if (tp_opt + fp_opt) > 0 else 0
# Calculate Recall
recall_opt = sensitivity_opt
# Calculate F1 Score
f1_score_opt = metrics.f1_score(predictions_df_val['Actual'], predictions_df_val['Final_Prediction'])

print(f"Sensitivity (Recall): {sensitivity_opt:.4f}")
print(f"Specificity: {specificity_opt:.4f}")
print(f"Precision: {precision_opt:.4f}")
print(f"Recall: {recall_opt:.4f}")
print(f"F1 Score: {f1_score_opt:.4f}")
# Out:
# Sensitivity (Recall): 0.6667
# Specificity: 0.8454
# Precision: 0.5946
# Recall: 0.6667
# F1 Score: 0.6286

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
print(X_val_rf_selected.columns)
# Make predictions on the validation data
y_val_rf_pred_selected = rf_model_selected.predict(X_val_rf_selected)
# Out:
# Index(['claim_per_vehicle', 'auto_model_freq', 'incident_hour_of_the_day',
#        'injury_claim', 'policy_annual_premium', 'policy_bind_month',
#        'auto_year'],
#       dtype='object')

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
rf_val_accuracy_selected = accuracy_score(y_val, y_val_rf_pred_selected)
rf_val_accuracy_selected
# Out:
# 0.7076923076923077

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_rf_val_selected = confusion_matrix(y_val, y_val_rf_pred_selected)
print("Confusion Matrix for validation data (Random Forest with selected features):")
print(conf_matrix_rf_val_selected)
# Out:
# Confusion Matrix for validation data (Random Forest with selected features):
# [[88  9]
#  [29  4]]

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_rf, fp_rf, fn_rf, tp_rf = confusion_matrix(y_val, y_val_rf_pred_selected).ravel()
print(f"True Positive (TP): {tp_rf}")
print(f"True Negative (TN): {tn_rf}")
print(f"False Positive (FP): {fp_rf}")
print(f"False Negative (FN): {fn_rf}")
# Out:
# True Positive (TP): 4
# True Negative (TN): 88
# False Positive (FP): 9
# False Negative (FN): 29

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf = tp_rf / (tp_rf + fn_rf) if (tp_rf + fn_rf) > 0 else 0

# Calculate the specificity
specificity_rf = tn_rf / (tn_rf + fp_rf) if (tn_rf + fp_rf) > 0 else 0


# Calculate Precision
precision_rf = tp_rf / (tp_rf + fp_rf) if (tp_rf + fp_rf) > 0 else 0


# Calculate Recall
recall_rf = sensitivity_rf


# Calculate F1 Score
f1_score_rf = metrics.f1_score(y_val, y_val_rf_pred_selected)

print(f"Sensitivity (Recall): {sensitivity_rf:.4f}")
print(f"Specificity: {specificity_rf:.4f}")
print(f"Precision: {precision_rf:.4f}")
print(f"Recall: {recall_rf:.4f}")
print(f"F1 Score: {f1_score_rf:.4f}")
# Out:
# Sensitivity (Recall): 0.1212
# Specificity: 0.9072
# Precision: 0.3077
# Recall: 0.1212
# F1 Score: 0.1739

# %% [markdown]
# ## **Evaluation and Conclusion**
#
#
# ### In case of Logistic Regression:
# #### model correctly identifies 66.67% of the actual positives
# #### model correctly identifies 84.54% of actual negatives
# #### Model 59.46% are actually true positives
# #### F1 score shows a much better balance between precision and recall.
#
# ### In case of Random Forest:
# #### The model correctly identifies 12.12% of the actual positives.
# #### The model correctly identifies 90.72% of the actual negatives.
# #### The model predicted positives, that 30.77% are true positives.
# #### f1 score reflecting poor balance between the recall and precision
#
#
# ##### Overall the Logistic regression is working good
